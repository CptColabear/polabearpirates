# %%
import csv

# CSV 파일 경로
csv_file_path = "C:/논문코드/데이터가공소/dataset/Adjacency_matricies/C_LOR.csv"

# 빈 리스트를 만들어 데이터를 저장할 준비
data = []
# 더할 값을 저장할 변수 초기화
row_sum = 0

# CSV 파일 열기
# with open(csv_file_path, newline='') as csvfile:
#     # CSV 파일 읽기
#     csv_reader = csv.reader(csvfile)
    
#     # 헤더 읽기 (첫 번째 행)
#     header = next(csv_reader)
#     print(header)
    
    # # 두 번째 행 읽기
    # second_row = next(csv_reader)
    # # 두 번째 행 출력
    # print(second_row)
    
    # third_row = next(csv_reader)
    # # 두 번째 행 출력
    # print(third_row)
    
    # # 특정 로우 선택 (예: 첫 번째 로우)
    # row_to_sum = next(csv_reader)
    # 로우 내의 값을 숫자로 변환하여 더하기
    # for row in csv_reader:
        
        # row_sum += float(value)
    
    
    # print(values)
    # for row in csv_reader:
    #     # 각 행의 열에 접근
    #     for column, value in zip(header, row):
    #         values = row.strip().split(";")
    
with open(csv_file_path, newline='') as csvfile:
    # CSV 파일 읽기
    csv_reader = csv.reader(csvfile, delimiter=';')  # 세미콜론으로 구분된 파일임을 지정
    
    # # 특정 로우 선택 (예: 첫 번째 로우)
    # row_to_process = next(csv_reader)
    
    # # 선택한 로우 내의 값을 리스트로 변환
    # values = row_to_process
    
    # 각 로우의 값을 저장할 리스트 초기화
    rows_values = []
    
    # CSV 파일의 각 로우에 대해서 반복
    for row in csv_reader:
        # 현재 로우의 값을 리스트로 변환하여 추가
        values = row
        rows_values.append(values)
