# %%
import math
import os
import pandas as pd
import glob
import numpy as np
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity
from dtaidistance import dtw
import csv
from pprint import pprint
import matplotlib.pyplot as plt
import copy

user_device_0 = 'C:\\논문코드\\데이터가공소\\dataset\\userdevice\\user-device_0.csv' #유저와 디바이스 관계
private_mobile_devices_0 = 'C:\\논문코드\\데이터가공소\\dataset\\mobiledevice\\private_mobile_devices_0.csv' #유저 디바이스 위치 시간

graph1 = 'C:\\논문코드\\데이터가공소\\dataset\\분석중\\time2.csv'
# graph1 = 'time2.csv'
user_device = open(graph1, 'r')
dictTime = {}

# %%
for line in user_device:
    line = line.replace('\n', '').split(',')

    if line[1] == 'id_user':
        continue

    xy = list(map(float, line[2:4]))
    time = line[4:6]

    allcol = xy + time

    if line[1] in dictTime:
        dictTime[line[1]].append(allcol)
    else:
        dictTime[line[1]] = [allcol]

listTime = list(dictTime.keys())
Graphmodeling = {}

for userid in listTime:
    Morning = []
    Afternoon = []
    Evening = []
    Night = []

    for line in dictTime[userid]:

        start = datetime.strptime(line[2], '%Y-%m-%d %H:%M:%S')  # str datetime 으로 타입변환
        stop = datetime.strptime(line[3], '%Y-%m-%d %H:%M:%S')

        x = int(line[0] / 0.015) # 일단 좌표로 찍어버리기 ( 튜플 )
        y = int(line[1] / 0.015)
        
        a = start.strftime('%H:%M:%S')
        b = stop.strftime('%H:%M:%S')
        
        z = (x,y)
       

        # 시간대 별로 나누어서 리스트에 저장
        if 5 <= start.hour <= 12:
                Morning.append(z)
                
        elif 10 <= start.hour <= 18:
                Afternoon.append(z)

        elif 16 <= start.hour <= 21:
                Evening.append(z)


        Graphmodeling[userid] = {}

        Graphmodeling[userid]['M'] = Morning
        Graphmodeling[userid]['A'] = Afternoon
        Graphmodeling[userid]['E'] = Evening

# %%
ptnlist = []
wjlist = []

for userid in Graphmodeling:

    for tmz in Graphmodeling[userid]:
        for ptn in Graphmodeling[userid][tmz]:
            wjdict = {}
            # print(userid)
            wjdict['user'] = userid
            # print(tmz)
            wjdict['time'] = tmz
            # print(ptn)
        
            if userid in wjdict:
                ptnlist.append(ptn)
            else:
                ptnlist = ptn
            
            wjdict['pattern'] = ptnlist
            # print(wjdict)
            wjlist.append(wjdict)

# %%
wjlist
# Out:
# [{'user': '685', 'time': 'M', 'pattern': (49, 38)},
#  {'user': '685', 'time': 'M', 'pattern': (49, 37)},
#  {'user': '685', 'time': 'M', 'pattern': (49, 40)},
#  {'user': '685', 'time': 'M', 'pattern': (18, 45)},
#  {'user': '685', 'time': 'M', 'pattern': (52, 39)},
#  {'user': '685', 'time': 'M', 'pattern': (42, 42)},
#  {'user': '685', 'time': 'M', 'pattern': (49, 31)},
#  {'user': '685', 'time': 'M', 'pattern': (51, 38)},
#  {'user': '685', 'time': 'M', 'pattern': (55, 38)},
#  {'user': '685', 'time': 'M', 'pattern': (49, 34)},
#  {'user': '685', 'time': 'M', 'pattern': (51, 40)},
#  {'user': '685', 'time': 'M', 'pattern': (52, 40)},
#  {'user': '685', 'time': 'M', 'pattern': (52, 6)},
#  {'user': '685', 'time': 'M', 'pattern': (34, 48)},
#  {'user': '685', 'time': 'M', 'pattern': (53, 40)},
#  {'user': '685', 'time': 'M', 'pattern': (38, 42)},
#  {'user': '685', 'time': 'M', 'pattern': (51, 35)},
#  {'user': '685', 'time': 'M', 'pattern': (48, 24)},
#  {'user': '685', 'time': 'M', 'pattern': (30, 52)},
#  {'user': '685', 'time': 'M', 'pattern': (50, 39)},
#  {'user': '685', 'time': 'M', 'pattern': (55, 34)},
#  {'user': '685', 'time': 'M', 'pattern': (53, 27)},
#  {'user': '685', 'time': 'M', 'pattern': (47, 38)},
#  {'user': '685', 'time': 'M', 'pattern': (55, 20)},
#  {'user': '685', 'time': 'M', 'pattern': (47, 38)},
#  {'user': '685', 'time': 'M', 'pattern': (51, 40)},
#  {'user': '685', 'time': 'M', 'pattern': (51, 42)},
#  {'user': '685', 'time': 'M', 'pattern': (46, 16)},
#  {'user': '685', 'time': 'M', 'pattern': (22, 50)},
#  {'user': '685', 'time': 'M', 'pattern': (52, 39)},
#  {'user': '685', 'time': 'M', 'pattern': (49, 40)},
#  {'user': '685', 'time': 'M', 'pattern': (47, 39)},
#  {'user': '685', 'time': 'M', 'pattern': (49, 31)},
#  {'user': '685', 'time': 'M', 'pattern': (18, 60)},
#  {'user': '685', 'time': 'M', 'pattern': (36, 61)},
#  {'user': '685', 'time': 'M', 'pattern': (44, 31)},
#  {'user': '685', 'time': 'M', 'pattern': (50, 43)},
#  {'user': '685', 'time': 'A', 'pattern': (51, 40)},
#  {'user': '685', 'time': 'A', 'pattern': (56, 41)},
#  {'user': '685', 'time': 'A', 'pattern': (51, 41)},
#  {'user': '685', 'time': 'A', 'pattern': (53, 38)},
#  {'user': '685', 'time': 'A', 'pattern': (53, 41)},
#  {'user': '685', 'time': 'A', 'pattern': (57, 41)},
#  {'user': '685', 'time': 'A', 'pattern': (49, 41)},
#  {'user': '685', 'time': 'A', 'pattern': (47, 34)},
#  {'user': '685', 'time': 'A', 'pattern': (51, 42)},
#  {'user': '685', 'time': 'A', 'pattern': (21, 21)},
#  {'user': '685', 'time': 'E', 'pattern': (57, 27)},
#  {'user': '685', 'time': 'E', 'pattern': (50, 39)},
#  {'user': '685', 'time': 'E', 'pattern': (58, 8)},
#  {'user': '685', 'time': 'E', 'pattern': (50, 33)},
#  {'user': '685', 'time': 'E', 'pattern': (20, 7)},
#  {'user': '685', 'time': 'E', 'pattern': (36, 31)},
#  {'user': '685', 'time': 'E', 'pattern': (53, 39)},
#  {'user': '685', 'time': 'E', 'pattern': (27, 64)},
#  {'user': '685', 'time': 'E', 'pattern': (46, 29)},
#  {'user': '685', 'time': 'E', 'pattern': (50, 40)},
#  {'user': '685', 'time': 'E', 'pattern': (54, 37)},
#  {'user': '685', 'time': 'E', 'pattern': (51, 36)},
#  {'user': '685', 'time': 'E', 'pattern': (55, 26)},
#  {'user': '1805', 'time': 'M', 'pattern': (16, 66)},
#  {'user': '1805', 'time': 'M', 'pattern': (22, 61)},
#  {'user': '1805', 'time': 'M', 'pattern': (3, 63)},
#  {'user': '1805', 'time': 'M', 'pattern': (14, 45)},
#  {'user': '1805', 'time': 'M', 'pattern': (3, 61)},
#  {'user': '1805', 'time': 'M', 'pattern': (10, 66)},
#  {'user': '1805', 'time': 'M', 'pattern': (10, 62)},
#  {'user': '1805', 'time': 'M', 'pattern': (13, 63)},
#  {'user': '1805', 'time': 'M', 'pattern': (14, 65)},
#  {'user': '1805', 'time': 'M', 'pattern': (11, 64)},
#  {'user': '1805', 'time': 'M', 'pattern': (16, 66)},
#  {'user': '1805', 'time': 'M', 'pattern': (9, 65)},
#  {'user': '1805', 'time': 'M', 'pattern': (12, 66)},
#  {'user': '1805', 'time': 'M', 'pattern': (33, 62)},
#  {'user': '1805', 'time': 'M', 'pattern': (11, 40)},
#  {'user': '1805', 'time': 'M', 'pattern': (12, 54)},
#  {'user': '1805', 'time': 'A', 'pattern': (26, 64)},
#  {'user': '1805', 'time': 'A', 'pattern': (25, 65)},
#  {'user': '1805', 'time': 'A', 'pattern': (10, 64)},
#  {'user': '1805', 'time': 'A', 'pattern': (32, 47)},
#  {'user': '1805', 'time': 'A', 'pattern': (24, 49)},
#  {'user': '1805', 'time': 'A', 'pattern': (12, 64)},
#  {'user': '1805', 'time': 'A', 'pattern': (6, 42)},
#  {'user': '1805', 'time': 'A', 'pattern': (12, 65)},
#  {'user': '1805', 'time': 'A', 'pattern': (8, 63)},
#  {'user': '1805', 'time': 'A', 'pattern': (7, 50)},
#  {'user': '1805', 'time': 'A', 'pattern': (58, 10)},
#  {'user': '1805', 'time': 'A', 'pattern': (22, 44)},
#  {'user': '1805', 'time': 'A', 'pattern': (11, 65)},
#  {'user': '1805', 'time': 'A', 'pattern': (21, 17)},
#  {'user': '1805', 'time': 'E', 'pattern': (11, 65)},
#  {'user': '1805', 'time': 'E', 'pattern': (33, 43)},
#  {'user': '1805', 'time': 'E', 'pattern': (6, 64)},
#  {'user': '1805', 'time': 'E', 'pattern': (20, 18)},
#  {'user': '1805', 'time': 'E', 'pattern': (12, 62)},
#  {'user': '1805', 'time': 'E', 'pattern': (14, 64)},
#  {'user': '1805', 'time': 'E', 'pattern': (10, 64)},
#  {'user': '1805', 'time': 'E', 'pattern': (14, 66)},
#  {'user': '1953', 'time': 'M', 'pattern': (60, 25)},
#  {'user': '1953', 'time': 'M', 'pattern': (21, 8)},
#  {'user': '1953', 'time': 'M', 'pattern': (22, 5)},
#  {'user': '1953', 'time': 'M', 'pattern': (36, 24)},
#  {'user': '1953', 'time': 'M', 'pattern': (19, 0)},
#  {'user': '1953', 'time': 'M', 'pattern': (19, 2)},
#  {'user': '1953', 'time': 'M', 'pattern': (15, 8)},
#  {'user': '1953', 'time': 'M', 'pattern': (34, 13)},
#  {'user': '1953', 'time': 'M', 'pattern': (22, 9)},
#  {'user': '1953', 'time': 'M', 'pattern': (13, 15)},
#  {'user': '1953', 'time': 'M', 'pattern': (15, 18)},
#  {'user': '1953', 'time': 'M', 'pattern': (13, 3)},
#  {'user': '1953', 'time': 'M', 'pattern': (20, 2)},
#  {'user': '1953', 'time': 'M', 'pattern': (23, 4)},
#  {'user': '1953', 'time': 'M', 'pattern': (23, 4)},
#  {'user': '1953', 'time': 'A', 'pattern': (39, 58)},
#  {'user': '1953', 'time': 'A', 'pattern': (25, 5)},
#  {'user': '1953', 'time': 'A', 'pattern': (20, 3)},
#  {'user': '1953', 'time': 'A', 'pattern': (21, 31)},
#  {'user': '1953', 'time': 'A', 'pattern': (32, 8)},
#  {'user': '1953', 'time': 'A', 'pattern': (11, 19)},
#  {'user': '1953', 'time': 'A', 'pattern': (17, 12)},
#  {'user': '1953', 'time': 'A', 'pattern': (11, 11)},
#  {'user': '1953', 'time': 'A', 'pattern': (15, 60)},
#  {'user': '1953', 'time': 'A', 'pattern': (19, 14)},
#  {'user': '1953', 'time': 'A', 'pattern': (11, 10)},
#  {'user': '1953', 'time': 'A', 'pattern': (16, 17)},
#  {'user': '1953', 'time': 'A', 'pattern': (14, 13)},
#  {'user': '1953', 'time': 'A', 'pattern': (15, 2)},
#  {'user': '1953', 'time': 'A', 'pattern': (20, 3)},
#  {'user': '1953', 'time': 'A', 'pattern': (7, 20)},
#  {'user': '1953', 'time': 'A', 'pattern': (49, 8)},
#  {'user': '1953', 'time': 'A', 'pattern': (7, 56)},
#  {'user': '1953', 'time': 'A', 'pattern': (7, 22)},
#  {'user': '1953', 'time': 'A', 'pattern': (22, 3)},
#  {'user': '1953', 'time': 'A', 'pattern': (20, 3)},
#  {'user': '1953', 'time': 'A', 'pattern': (19, 1)},
#  {'user': '1953', 'time': 'A', 'pattern': (17, 2)},
#  {'user': '1953', 'time': 'A', 'pattern': (6, 7)},
#  {'user': '1953', 'time': 'A', 'pattern': (24, 4)},
#  {'user': '1953', 'time': 'A', 'pattern': (14, 7)},
#  {'user': '1953', 'time': 'A', 'pattern': (5, 25)},
#  {'user': '1953', 'time': 'A', 'pattern': (31, 4)},
#  {'user': '1953', 'time': 'A', 'pattern': (31, 9)},
#  {'user': '1953', 'time': 'A', 'pattern': (36, 8)},
#  {'user': '1953', 'time': 'A', 'pattern': (10, 8)},
#  {'user': '1953', 'time': 'A', 'pattern': (19, 2)},
#  {'user': '1953', 'time': 'A', 'pattern': (20, 5)},
#  {'user': '1953', 'time': 'A', 'pattern': (21, 3)},
#  {'user': '1953', 'time': 'A', 'pattern': (20, 7)},
#  {'user': '1953', 'time': 'A', 'pattern': (24, 13)},
#  {'user': '1953', 'time': 'A', 'pattern': (19, 2)},
#  {'user': '1953', 'time': 'A', 'pattern': (40, 15)},
#  {'user': '1953', 'time': 'A', 'pattern': (39, 3)},
#  {'user': '1953', 'time': 'E', 'pattern': (16, 10)},
#  {'user': '1953', 'time': 'E', 'pattern': (19, 2)},
#  {'user': '1953', 'time': 'E', 'pattern': (21, 38)},
#  {'user': '1953', 'time': 'E', 'pattern': (20, 3)},
#  {'user': '1953', 'time': 'E', 'pattern': (43, 13)},
#  {'user': '1953', 'time': 'E', 'pattern': (18, 3)},
#  {'user': '1953', 'time': 'E', 'pattern': (17, 8)},
#  {'user': '1953', 'time': 'E', 'pattern': (55, 27)},
#  {'user': '2449', 'time': 'M', 'pattern': (63, 41)},
#  {'user': '2449', 'time': 'M', 'pattern': (53, 34)},
#  {'user': '2449', 'time': 'M', 'pattern': (49, 36)},
#  {'user': '2449', 'time': 'M', 'pattern': (51, 30)},
#  {'user': '2449', 'time': 'M', 'pattern': (49, 33)},
#  {'user': '2449', 'time': 'M', 'pattern': (43, 42)},
#  {'user': '2449', 'time': 'M', 'pattern': (30, 38)},
#  {'user': '2449', 'time': 'M', 'pattern': (55, 37)},
#  {'user': '2449', 'time': 'M', 'pattern': (47, 41)},
#  {'user': '2449', 'time': 'M', 'pattern': (50, 41)},
#  {'user': '2449', 'time': 'M', 'pattern': (46, 38)},
#  {'user': '2449', 'time': 'M', 'pattern': (48, 38)},
#  {'user': '2449', 'time': 'M', 'pattern': (42, 44)},
#  {'user': '2449', 'time': 'M', 'pattern': (47, 38)},
#  {'user': '2449', 'time': 'M', 'pattern': (46, 38)},
#  {'user': '2449', 'time': 'M', 'pattern': (46, 37)},
#  {'user': '2449', 'time': 'M', 'pattern': (47, 39)},
#  {'user': '2449', 'time': 'M', 'pattern': (39, 42)},
#  {'user': '2449', 'time': 'M', 'pattern': (27, 43)},
#  {'user': '2449', 'time': 'M', 'pattern': (47, 39)},
#  {'user': '2449', 'time': 'M', 'pattern': (46, 35)},
#  {'user': '2449', 'time': 'A', 'pattern': (65, 13)},
#  {'user': '2449', 'time': 'A', 'pattern': (47, 37)},
#  {'user': '2449', 'time': 'A', 'pattern': (38, 36)},
#  {'user': '2449', 'time': 'A', 'pattern': (48, 38)},
#  {'user': '2449', 'time': 'A', 'pattern': (40, 24)},
#  {'user': '2449', 'time': 'A', 'pattern': (50, 33)},
#  {'user': '2449', 'time': 'A', 'pattern': (38, 27)},
#  {'user': '2449', 'time': 'A', 'pattern': (50, 41)},
#  {'user': '2449', 'time': 'E', 'pattern': (49, 38)},
#  {'user': '2332', 'time': 'M', 'pattern': (19, 14)},
#  {'user': '2332', 'time': 'M', 'pattern': (1, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (12, 3)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 41)},
#  {'user': '2332', 'time': 'M', 'pattern': (12, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (9, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (13, 0)},
#  {'user': '2332', 'time': 'M', 'pattern': (10, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (11, 5)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (18, 11)},
#  {'user': '2332', 'time': 'M', 'pattern': (16, 7)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 3)},
#  {'user': '2332', 'time': 'M', 'pattern': (23, 7)},
#  {'user': '2332', 'time': 'M', 'pattern': (16, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 5)},
#  {'user': '2332', 'time': 'M', 'pattern': (11, 23)},
#  {'user': '2332', 'time': 'M', 'pattern': (17, 3)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 11)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 5)},
#  {'user': '2332', 'time': 'M', 'pattern': (13, 3)},
#  {'user': '2332', 'time': 'M', 'pattern': (13, 5)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (17, 25)},
#  {'user': '2332', 'time': 'M', 'pattern': (6, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (0, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 3)},
#  {'user': '2332', 'time': 'M', 'pattern': (13, 8)},
#  {'user': '2332', 'time': 'M', 'pattern': (21, 5)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (11, 18)},
#  {'user': '2332', 'time': 'M', 'pattern': (13, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (7, 2)},
#  {'user': '2332', 'time': 'M', 'pattern': (27, 24)},
#  {'user': '2332', 'time': 'M', 'pattern': (9, 15)},
#  {'user': '2332', 'time': 'M', 'pattern': (48, 27)},
#  {'user': '2332', 'time': 'M', 'pattern': (16, 5)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 9)},
#  {'user': '2332', 'time': 'M', 'pattern': (9, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (11, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (15, 6)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 58)},
#  {'user': '2332', 'time': 'M', 'pattern': (20, 0)},
#  {'user': '2332', 'time': 'M', 'pattern': (17, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (27, 23)},
#  {'user': '2332', 'time': 'M', 'pattern': (27, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (5, 4)},
#  {'user': '2332', 'time': 'M', 'pattern': (17, 12)},
#  {'user': '2332', 'time': 'M', 'pattern': (10, 1)},
#  {'user': '2332', 'time': 'M', 'pattern': (14, 3)},
#  {'user': '2332', 'time': 'M', 'pattern': (7, 43)},
#  {'user': '2332', 'time': 'M', 'pattern': (13, 3)},
#  {'user': '2332', 'time': 'A', 'pattern': (17, 6)},
#  {'user': '2332', 'time': 'A', 'pattern': (21, 4)},
#  {'user': '2332', 'time': 'A', 'pattern': (14, 2)},
#  {'user': '2332', 'time': 'A', 'pattern': (12, 3)},
#  {'user': '2332', 'time': 'A', 'pattern': (13, 2)},
#  {'user': '2332', 'time': 'A', 'pattern': (15, 2)},
#  {'user': '2332', 'time': 'A', 'pattern': (14, 4)},
#  {'user': '2332', 'time': 'A', 'pattern': (17, 4)},
#  {'user': '2332', 'time': 'A', 'pattern': (8, 10)},
#  {'user': '2332', 'time': 'A', 'pattern': (11, 2)},
#  {'user': '2332', 'time': 'A', 'pattern': (22, 14)},
#  {'user': '2332', 'time': 'A', 'pattern': (14, 5)},
#  {'user': '2332', 'time': 'A', 'pattern': (16, 6)},
#  {'user': '2332', 'time': 'A', 'pattern': (19, 1)},
#  {'user': '2332', 'time': 'E', 'pattern': (16, 46)},
#  {'user': '2332', 'time': 'E', 'pattern': (63, 19)},
#  {'user': '2332', 'time': 'E', 'pattern': (14, 3)},
#  {'user': '2332', 'time': 'E', 'pattern': (18, 12)},
#  {'user': '2332', 'time': 'E', 'pattern': (28, 22)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (20, 2)},
#  {'user': '545', 'time': 'M', 'pattern': (22, 28)},
#  {'user': '545', 'time': 'M', 'pattern': (21, 12)},
#  {'user': '545', 'time': 'M', 'pattern': (4, 10)},
#  {'user': '545', 'time': 'M', 'pattern': (12, 9)},
#  {'user': '545', 'time': 'M', 'pattern': (34, 2)},
#  {'user': '545', 'time': 'M', 'pattern': (10, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (39, 49)},
#  {'user': '545', 'time': 'M', 'pattern': (11, 0)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (11, 11)},
#  {'user': '545', 'time': 'M', 'pattern': (14, 13)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 4)},
#  {'user': '545', 'time': 'M', 'pattern': (1, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (3, 2)},
#  {'user': '545', 'time': 'M', 'pattern': (12, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (52, 16)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (30, 42)},
#  {'user': '545', 'time': 'M', 'pattern': (30, 43)},
#  {'user': '545', 'time': 'M', 'pattern': (9, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (24, 35)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 2)},
#  {'user': '545', 'time': 'M', 'pattern': (9, 18)},
#  {'user': '545', 'time': 'M', 'pattern': (31, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (3, 11)},
#  {'user': '545', 'time': 'M', 'pattern': (12, 25)},
#  {'user': '545', 'time': 'M', 'pattern': (2, 26)},
#  {'user': '545', 'time': 'M', 'pattern': (2, 1)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 4)},
#  {'user': '545', 'time': 'M', 'pattern': (8, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 9)},
#  {'user': '545', 'time': 'M', 'pattern': (3, 12)},
#  {'user': '545', 'time': 'M', 'pattern': (8, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (4, 4)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 2)},
#  {'user': '545', 'time': 'M', 'pattern': (51, 34)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (29, 50)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (9, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (35, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (13, 11)},
#  {'user': '545', 'time': 'M', 'pattern': (14, 26)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 4)},
#  {'user': '545', 'time': 'M', 'pattern': (16, 14)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 2)},
#  {'user': '545', 'time': 'M', 'pattern': (2, 3)},
#  {'user': '545', 'time': 'M', 'pattern': (4, 24)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (62, 40)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 4)},
#  {'user': '545', 'time': 'M', 'pattern': (8, 1)},
#  {'user': '545', 'time': 'M', 'pattern': (14, 23)},
#  {'user': '545', 'time': 'M', 'pattern': (8, 4)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 10)},
#  {'user': '545', 'time': 'M', 'pattern': (12, 13)},
#  {'user': '545', 'time': 'M', 'pattern': (38, 44)},
#  {'user': '545', 'time': 'M', 'pattern': (9, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (12, 22)},
#  {'user': '545', 'time': 'M', 'pattern': (18, 11)},
#  {'user': '545', 'time': 'M', 'pattern': (15, 9)},
#  {'user': '545', 'time': 'M', 'pattern': (9, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (37, 40)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (1, 7)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 11)},
#  {'user': '545', 'time': 'M', 'pattern': (4, 12)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (8, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (10, 37)},
#  {'user': '545', 'time': 'M', 'pattern': (2, 6)},
#  {'user': '545', 'time': 'M', 'pattern': (9, 3)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 9)},
#  {'user': '545', 'time': 'M', 'pattern': (5, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (7, 3)},
#  {'user': '545', 'time': 'M', 'pattern': (6, 5)},
#  {'user': '545', 'time': 'M', 'pattern': (10, 8)},
#  {'user': '545', 'time': 'M', 'pattern': (3, 8)},
#  {'user': '545', 'time': 'A', 'pattern': (9, 7)},
#  {'user': '545', 'time': 'A', 'pattern': (4, 0)},
#  {'user': '545', 'time': 'A', 'pattern': (8, 3)},
#  {'user': '545', 'time': 'A', 'pattern': (6, 1)},
#  {'user': '545', 'time': 'A', 'pattern': (4, 24)},
#  {'user': '545', 'time': 'A', 'pattern': (11, 4)},
#  {'user': '545', 'time': 'A', 'pattern': (6, 3)},
#  {'user': '545', 'time': 'A', 'pattern': (3, 6)},
#  {'user': '545', 'time': 'A', 'pattern': (2, 6)},
#  {'user': '545', 'time': 'A', 'pattern': (52, 12)},
#  {'user': '545', 'time': 'A', 'pattern': (6, 5)},
#  {'user': '545', 'time': 'A', 'pattern': (9, 1)},
#  {'user': '545', 'time': 'A', 'pattern': (1, 11)},
#  {'user': '545', 'time': 'A', 'pattern': (3, 6)},
#  {'user': '545', 'time': 'A', 'pattern': (6, 4)},
#  {'user': '545', 'time': 'A', 'pattern': (9, 5)},
#  {'user': '545', 'time': 'A', 'pattern': (5, 21)},
#  {'user': '545', 'time': 'A', 'pattern': (3, 17)},
#  {'user': '545', 'time': 'A', 'pattern': (4, 6)},
#  {'user': '545', 'time': 'A', 'pattern': (22, 21)},
#  {'user': '545', 'time': 'A', 'pattern': (1, 7)},
#  {'user': '545', 'time': 'A', 'pattern': (8, 9)},
#  {'user': '545', 'time': 'A', 'pattern': (5, 13)},
#  {'user': '545', 'time': 'A', 'pattern': (4, 5)},
#  {'user': '545', 'time': 'A', 'pattern': (11, 6)},
#  {'user': '545', 'time': 'A', 'pattern': (4, 7)},
#  {'user': '545', 'time': 'A', 'pattern': (5, 55)},
#  {'user': '545', 'time': 'A', 'pattern': (11, 4)},
#  {'user': '545', 'time': 'A', 'pattern': (12, 4)},
#  {'user': '545', 'time': 'A', 'pattern': (5, 6)},
#  {'user': '545', 'time': 'A', 'pattern': (5, 8)},
#  {'user': '545', 'time': 'A', 'pattern': (9, 10)},
#  {'user': '545', 'time': 'A', 'pattern': (17, 7)},
#  {'user': '545', 'time': 'A', 'pattern': (43, 15)},
#  {'user': '545', 'time': 'A', 'pattern': (13, 22)},
#  {'user': '545', 'time': 'A', 'pattern': (2, 2)},
#  {'user': '545', 'time': 'A', 'pattern': (34, 7)},
#  {'user': '545', 'time': 'A', 'pattern': (7, 7)},
#  {'user': '545', 'time': 'A', 'pattern': (6, 8)},
#  {'user': '545', 'time': 'A', 'pattern': (12, 14)},
#  {'user': '545', 'time': 'E', 'pattern': (7, 6)},
#  {'user': '545', 'time': 'E', 'pattern': (7, 7)},
#  {'user': '545', 'time': 'E', 'pattern': (10, 12)},
#  {'user': '2823', 'time': 'M', 'pattern': (22, 34)},
#  {'user': '2823', 'time': 'M', 'pattern': (26, 38)},
#  {'user': '2823', 'time': 'M', 'pattern': (10, 36)},
#  {'user': '2823', 'time': 'M', 'pattern': (7, 51)},
#  {'user': '2823', 'time': 'M', 'pattern': (2, 37)},
#  {'user': '2823', 'time': 'M', 'pattern': (19, 34)},
#  {'user': '2823', 'time': 'M', 'pattern': (33, 41)},
#  {'user': '2823', 'time': 'M', 'pattern': (25, 35)},
#  {'user': '2823', 'time': 'M', 'pattern': (28, 30)},
#  {'user': '2823', 'time': 'M', 'pattern': (21, 39)},
#  {'user': '2823', 'time': 'M', 'pattern': (24, 31)},
#  {'user': '2823', 'time': 'M', 'pattern': (34, 10)},
#  {'user': '2823', 'time': 'M', 'pattern': (5, 32)},
#  {'user': '2823', 'time': 'M', 'pattern': (25, 36)},
#  {'user': '2823', 'time': 'M', 'pattern': (13, 38)},
#  {'user': '2823', 'time': 'M', 'pattern': (21, 36)},
#  {'user': '2823', 'time': 'M', 'pattern': (21, 35)},
#  {'user': '2823', 'time': 'M', 'pattern': (11, 32)},
#  {'user': '2823', 'time': 'M', 'pattern': (22, 34)},
#  {'user': '2823', 'time': 'M', 'pattern': (8, 27)},
#  {'user': '2823', 'time': 'M', 'pattern': (32, 40)},
#  {'user': '2823', 'time': 'M', 'pattern': (24, 37)},
#  {'user': '2823', 'time': 'M', 'pattern': (9, 39)},
#  {'user': '2823', 'time': 'M', 'pattern': (16, 38)},
#  {'user': '2823', 'time': 'M', 'pattern': (5, 16)},
#  {'user': '2823', 'time': 'M', 'pattern': (31, 49)},
#  {'user': '2823', 'time': 'M', 'pattern': (23, 22)},
#  {'user': '2823', 'time': 'M', 'pattern': (18, 31)},
#  {'user': '2823', 'time': 'A', 'pattern': (27, 45)},
#  {'user': '2823', 'time': 'A', 'pattern': (16, 50)},
#  {'user': '2823', 'time': 'A', 'pattern': (10, 15)},
#  {'user': '2823', 'time': 'A', 'pattern': (17, 53)},
#  {'user': '2823', 'time': 'A', 'pattern': (19, 39)},
#  {'user': '2823', 'time': 'A', 'pattern': (20, 41)},
#  {'user': '2823', 'time': 'A', 'pattern': (23, 44)},
#  {'user': '2823', 'time': 'A', 'pattern': (20, 28)},
#  {'user': '2823', 'time': 'E', 'pattern': (4, 39)},
#  {'user': '2823', 'time': 'E', 'pattern': (21, 33)},
#  {'user': '2823', 'time': 'E', 'pattern': (34, 36)},
#  {'user': '2823', 'time': 'E', 'pattern': (21, 33)},
#  {'user': '2823', 'time': 'E', 'pattern': (22, 28)},
#  {'user': '2823', 'time': 'E', 'pattern': (22, 40)},
#  {'user': '3423', 'time': 'M', 'pattern': (37, 3)},
#  {'user': '3423', 'time': 'M', 'pattern': (46, 29)},
#  {'user': '3423', 'time': 'M', 'pattern': (28, 17)},
#  {'user': '3423', 'time': 'M', 'pattern': (31, 24)},
#  {'user': '3423', 'time': 'M', 'pattern': (40, 16)},
#  {'user': '3423', 'time': 'M', 'pattern': (24, 26)},
#  {'user': '3423', 'time': 'M', 'pattern': (31, 20)},
#  {'user': '3423', 'time': 'M', 'pattern': (43, 31)},
#  {'user': '3423', 'time': 'M', 'pattern': (32, 24)},
#  {'user': '3423', 'time': 'M', 'pattern': (4, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (51, 19)},
#  {'user': '3423', 'time': 'M', 'pattern': (34, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (33, 26)},
#  {'user': '3423', 'time': 'M', 'pattern': (19, 52)},
#  {'user': '3423', 'time': 'M', 'pattern': (41, 47)},
#  {'user': '3423', 'time': 'M', 'pattern': (6, 29)},
#  {'user': '3423', 'time': 'M', 'pattern': (28, 17)},
#  {'user': '3423', 'time': 'M', 'pattern': (35, 8)},
#  {'user': '3423', 'time': 'M', 'pattern': (41, 37)},
#  {'user': '3423', 'time': 'M', 'pattern': (35, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (34, 27)},
#  {'user': '3423', 'time': 'M', 'pattern': (36, 21)},
#  {'user': '3423', 'time': 'M', 'pattern': (29, 16)},
#  {'user': '3423', 'time': 'M', 'pattern': (33, 24)},
#  {'user': '3423', 'time': 'M', 'pattern': (39, 19)},
#  {'user': '3423', 'time': 'M', 'pattern': (34, 22)},
#  {'user': '3423', 'time': 'M', 'pattern': (20, 34)},
#  {'user': '3423', 'time': 'M', 'pattern': (28, 19)},
#  {'user': '3423', 'time': 'M', 'pattern': (41, 37)},
#  {'user': '3423', 'time': 'M', 'pattern': (36, 20)},
#  {'user': '3423', 'time': 'M', 'pattern': (34, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (16, 19)},
#  {'user': '3423', 'time': 'M', 'pattern': (34, 18)},
#  {'user': '3423', 'time': 'M', 'pattern': (50, 19)},
#  {'user': '3423', 'time': 'M', 'pattern': (41, 16)},
#  {'user': '3423', 'time': 'M', 'pattern': (31, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (25, 16)},
#  {'user': '3423', 'time': 'M', 'pattern': (36, 26)},
#  {'user': '3423', 'time': 'M', 'pattern': (33, 25)},
#  {'user': '3423', 'time': 'M', 'pattern': (39, 30)},
#  {'user': '3423', 'time': 'M', 'pattern': (33, 24)},
#  {'user': '3423', 'time': 'M', 'pattern': (35, 24)},
#  {'user': '3423', 'time': 'M', 'pattern': (32, 27)},
#  {'user': '3423', 'time': 'M', 'pattern': (35, 32)},
#  {'user': '3423', 'time': 'M', 'pattern': (27, 25)},
#  {'user': '3423', 'time': 'M', 'pattern': (50, 32)},
#  {'user': '3423', 'time': 'M', 'pattern': (35, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (24, 14)},
#  {'user': '3423', 'time': 'M', 'pattern': (36, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (38, 18)},
#  {'user': '3423', 'time': 'M', 'pattern': (40, 14)},
#  {'user': '3423', 'time': 'M', 'pattern': (33, 26)},
#  {'user': '3423', 'time': 'M', 'pattern': (15, 14)},
#  {'user': '3423', 'time': 'M', 'pattern': (54, 41)},
#  {'user': '3423', 'time': 'M', 'pattern': (54, 15)},
#  {'user': '3423', 'time': 'M', 'pattern': (50, 18)},
#  {'user': '3423', 'time': 'M', 'pattern': (38, 19)},
#  {'user': '3423', 'time': 'M', 'pattern': (40, 31)},
#  {'user': '3423', 'time': 'M', 'pattern': (34, 22)},
#  {'user': '3423', 'time': 'M', 'pattern': (2, 23)},
#  {'user': '3423', 'time': 'M', 'pattern': (64, 9)},
#  {'user': '3423', 'time': 'M', 'pattern': (32, 24)},
#  {'user': '3423', 'time': 'M', 'pattern': (2, 6)},
#  {'user': '3423', 'time': 'M', 'pattern': (38, 28)},
#  {'user': '3423', 'time': 'M', 'pattern': (38, 22)},
#  {'user': '3423', 'time': 'M', 'pattern': (36, 25)},
#  {'user': '3423', 'time': 'M', 'pattern': (38, 2)},
#  {'user': '3423', 'time': 'M', 'pattern': (19, 28)},
#  {'user': '3423', 'time': 'A', 'pattern': (35, 22)},
#  {'user': '3423', 'time': 'A', 'pattern': (33, 23)},
#  {'user': '3423', 'time': 'A', 'pattern': (29, 23)},
#  {'user': '3423', 'time': 'A', 'pattern': (36, 24)},
#  {'user': '3423', 'time': 'A', 'pattern': (55, 32)},
#  {'user': '3423', 'time': 'A', 'pattern': (57, 13)},
#  {'user': '3423', 'time': 'A', 'pattern': (35, 10)},
#  {'user': '3423', 'time': 'A', 'pattern': (45, 34)},
#  {'user': '3423', 'time': 'A', 'pattern': (38, 23)},
#  {'user': '3423', 'time': 'A', 'pattern': (10, 14)},
#  {'user': '3423', 'time': 'A', 'pattern': (34, 23)},
#  {'user': '3423', 'time': 'A', 'pattern': (29, 28)},
#  {'user': '3423', 'time': 'A', 'pattern': (33, 31)},
#  {'user': '3423', 'time': 'A', 'pattern': (34, 24)},
#  {'user': '3423', 'time': 'A', 'pattern': (50, 13)},
#  {'user': '3423', 'time': 'A', 'pattern': (23, 53)},
#  {'user': '3423', 'time': 'A', 'pattern': (40, 23)},
#  {'user': '3423', 'time': 'A', 'pattern': (65, 16)},
#  {'user': '3423', 'time': 'A', 'pattern': (47, 17)},
#  {'user': '3423', 'time': 'A', 'pattern': (8, 61)},
#  {'user': '3423', 'time': 'A', 'pattern': (38, 24)},
#  {'user': '3423', 'time': 'A', 'pattern': (35, 23)},
#  {'user': '3423', 'time': 'A', 'pattern': (32, 20)},
#  {'user': '3423', 'time': 'A', 'pattern': (35, 24)},
#  {'user': '3423', 'time': 'A', 'pattern': (37, 25)},
#  {'user': '3423', 'time': 'A', 'pattern': (60, 33)},
#  {'user': '3423', 'time': 'A', 'pattern': (50, 36)},
#  {'user': '3423', 'time': 'E', 'pattern': (27, 28)},
#  {'user': '3423', 'time': 'E', 'pattern': (39, 29)},
#  {'user': '3423', 'time': 'E', 'pattern': (36, 24)},
#  {'user': '3423', 'time': 'E', 'pattern': (34, 23)},
#  {'user': '3423', 'time': 'E', 'pattern': (36, 24)},
#  {'user': '3423', 'time': 'E', 'pattern': (36, 23)},
#  {'user': '3423', 'time': 'E', 'pattern': (22, 26)},
#  {'user': '3423', 'time': 'E', 'pattern': (28, 24)},
#  {'user': '3423', 'time': 'E', 'pattern': (34, 27)},
#  {'user': '3423', 'time': 'E', 'pattern': (37, 45)},
#  {'user': '3423', 'time': 'E', 'pattern': (59, 31)},
#  {'user': '1750', 'time': 'M', 'pattern': (66, 6)},
#  {'user': '1750', 'time': 'M', 'pattern': (65, 7)},
#  {'user': '1750', 'time': 'M', 'pattern': (30, 20)},
#  {'user': '1750', 'time': 'M', 'pattern': (60, 19)},
#  {'user': '1750', 'time': 'M', 'pattern': (65, 8)},
#  {'user': '1750', 'time': 'M', 'pattern': (66, 9)},
#  {'user': '1750', 'time': 'M', 'pattern': (64, 10)},
#  {'user': '1750', 'time': 'M', 'pattern': (66, 8)},
#  {'user': '1750', 'time': 'M', 'pattern': (66, 0)},
#  {'user': '1750', 'time': 'M', 'pattern': (65, 10)},
#  {'user': '1750', 'time': 'A', 'pattern': (64, 6)},
#  {'user': '1750', 'time': 'A', 'pattern': (65, 10)},
#  {'user': '1750', 'time': 'A', 'pattern': (32, 11)},
#  {'user': '1750', 'time': 'A', 'pattern': (44, 37)},
#  {'user': '1750', 'time': 'A', 'pattern': (5, 9)},
#  {'user': '1750', 'time': 'A', 'pattern': (63, 12)},
#  {'user': '1750', 'time': 'A', 'pattern': (53, 34)},
#  {'user': '1750', 'time': 'A', 'pattern': (65, 30)},
#  {'user': '1750', 'time': 'A', 'pattern': (52, 33)},
#  {'user': '1750', 'time': 'A', 'pattern': (49, 10)},
#  {'user': '1750', 'time': 'A', 'pattern': (52, 9)},
#  {'user': '1750', 'time': 'A', 'pattern': (66, 10)},
#  {'user': '1750', 'time': 'A', 'pattern': (4, 4)},
#  {'user': '1750', 'time': 'A', 'pattern': (64, 15)},
#  {'user': '1750', 'time': 'A', 'pattern': (65, 8)},
#  {'user': '1750', 'time': 'A', 'pattern': (54, 9)},
#  {'user': '1750', 'time': 'A', 'pattern': (66, 7)},
#  {'user': '1750', 'time': 'A', 'pattern': (64, 6)},
#  {'user': '1750', 'time': 'A', 'pattern': (62, 16)},
#  {'user': '1750', 'time': 'A', 'pattern': (63, 9)},
#  {'user': '1750', 'time': 'A', 'pattern': (41, 8)},
#  {'user': '1750', 'time': 'A', 'pattern': (37, 31)},
#  {'user': '1750', 'time': 'A', 'pattern': (38, 36)},
#  {'user': '1750', 'time': 'A', 'pattern': (34, 3)},
#  {'user': '1750', 'time': 'E', 'pattern': (35, 45)},
#  {'user': '1750', 'time': 'E', 'pattern': (65, 16)},
#  {'user': '1750', 'time': 'E', 'pattern': (60, 39)},
#  {'user': '1750', 'time': 'E', 'pattern': (64, 10)},
#  {'user': '1750', 'time': 'E', 'pattern': (45, 35)},
#  {'user': '1750', 'time': 'E', 'pattern': (51, 32)},
#  {'user': '1750', 'time': 'E', 'pattern': (63, 7)},
#  {'user': '1750', 'time': 'E', 'pattern': (64, 13)},
#  {'user': '1750', 'time': 'E', 'pattern': (60, 12)},
#  {'user': '1750', 'time': 'E', 'pattern': (65, 10)},
#  {'user': '1750', 'time': 'E', 'pattern': (64, 6)},
#  {'user': '1750', 'time': 'E', 'pattern': (65, 11)},
#  {'user': '1750', 'time': 'E', 'pattern': (47, 22)},
#  {'user': '1750', 'time': 'E', 'pattern': (49, 2)},
#  {'user': '1750', 'time': 'E', 'pattern': (61, 6)},
#  {'user': '1750', 'time': 'E', 'pattern': (64, 9)},
#  {'user': '1750', 'time': 'E', 'pattern': (62, 28)},
#  {'user': '1750', 'time': 'E', 'pattern': (37, 28)},
#  {'user': '3547', 'time': 'M', 'pattern': (40, 49)},
#  {'user': '3547', 'time': 'M', 'pattern': (58, 21)},
#  {'user': '3547', 'time': 'M', 'pattern': (61, 36)},
#  {'user': '3547', 'time': 'M', 'pattern': (60, 23)},
#  {'user': '3547', 'time': 'M', 'pattern': (65, 27)},
#  {'user': '3547', 'time': 'M', 'pattern': (28, 10)},
#  {'user': '3547', 'time': 'M', 'pattern': (56, 19)},
#  {'user': '3547', 'time': 'A', 'pattern': (25, 23)},
#  {'user': '3547', 'time': 'A', 'pattern': (37, 12)},
#  {'user': '3547', 'time': 'A', 'pattern': (52, 17)},
#  {'user': '3547', 'time': 'A', 'pattern': (62, 16)},
#  {'user': '3547', 'time': 'A', 'pattern': (62, 15)},
#  {'user': '3547', 'time': 'E', 'pattern': (57, 13)},
#  {'user': '3547', 'time': 'E', 'pattern': (61, 15)},
#  {'user': '3547', 'time': 'E', 'pattern': (39, 0)},
#  {'user': '3547', 'time': 'E', 'pattern': (57, 19)},
#  {'user': '3547', 'time': 'E', 'pattern': (64, 24)},
#  {'user': '3547', 'time': 'E', 'pattern': (61, 15)},
#  {'user': '1280', 'time': 'M', 'pattern': (10, 9)},
#  {'user': '1280', 'time': 'M', 'pattern': (11, 6)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 7)},
#  {'user': '1280', 'time': 'M', 'pattern': (4, 6)},
#  {'user': '1280', 'time': 'M', 'pattern': (5, 11)},
#  {'user': '1280', 'time': 'M', 'pattern': (8, 10)},
#  {'user': '1280', 'time': 'M', 'pattern': (0, 56)},
#  {'user': '1280', 'time': 'M', 'pattern': (47, 18)},
#  {'user': '1280', 'time': 'M', 'pattern': (12, 41)},
#  {'user': '1280', 'time': 'M', 'pattern': (13, 21)},
#  {'user': '1280', 'time': 'M', 'pattern': (16, 5)},
#  {'user': '1280', 'time': 'M', 'pattern': (13, 26)},
#  {'user': '1280', 'time': 'M', 'pattern': (12, 33)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 3)},
#  {'user': '1280', 'time': 'M', 'pattern': (12, 33)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 4)},
#  {'user': '1280', 'time': 'M', 'pattern': (3, 7)},
#  {'user': '1280', 'time': 'M', 'pattern': (6, 10)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 4)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 4)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 7)},
#  {'user': '1280', 'time': 'M', 'pattern': (9, 0)},
#  {'user': '1280', 'time': 'M', 'pattern': (8, 5)},
#  {'user': '1280', 'time': 'M', 'pattern': (11, 9)},
#  {'user': '1280', 'time': 'M', 'pattern': (4, 12)},
#  {'user': '1280', 'time': 'M', 'pattern': (8, 8)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 9)},
#  {'user': '1280', 'time': 'M', 'pattern': (9, 5)},
#  {'user': '1280', 'time': 'M', 'pattern': (51, 4)},
#  {'user': '1280', 'time': 'M', 'pattern': (6, 6)},
#  {'user': '1280', 'time': 'M', 'pattern': (7, 5)},
#  {'user': '1280', 'time': 'M', 'pattern': (11, 9)},
#  {'user': '1280', 'time': 'M', 'pattern': (10, 10)},
#  {'user': '1280', 'time': 'M', 'pattern': (12, 9)},
#  {'user': '1280', 'time': 'M', 'pattern': (13, 1)},
#  {'user': '1280', 'time': 'M', 'pattern': (15, 1)},
#  {'user': '1280', 'time': 'M', 'pattern': (6, 14)},
#  {'user': '1280', 'time': 'M', 'pattern': (22, 13)},
#  {'user': '1280', 'time': 'M', 'pattern': (11, 15)},
#  {'user': '1280', 'time': 'M', 'pattern': (20, 9)},
#  {'user': '1280', 'time': 'M', 'pattern': (6, 29)},
#  {'user': '1280', 'time': 'M', 'pattern': (11, 32)},
#  {'user': '1280', 'time': 'M', 'pattern': (33, 10)},
#  {'user': '1280', 'time': 'M', 'pattern': (5, 6)},
#  {'user': '1280', 'time': 'M', 'pattern': (5, 5)},
#  {'user': '1280', 'time': 'A', 'pattern': (9, 15)},
#  {'user': '1280', 'time': 'A', 'pattern': (10, 10)},
#  {'user': '1280', 'time': 'A', 'pattern': (11, 8)},
#  {'user': '1280', 'time': 'A', 'pattern': (45, 16)},
#  {'user': '1280', 'time': 'A', 'pattern': (2, 59)},
#  {'user': '1280', 'time': 'A', 'pattern': (43, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (1, 20)},
#  {'user': '1280', 'time': 'A', 'pattern': (20, 18)},
#  {'user': '1280', 'time': 'A', 'pattern': (5, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (6, 7)},
#  {'user': '1280', 'time': 'A', 'pattern': (49, 10)},
#  {'user': '1280', 'time': 'A', 'pattern': (8, 8)},
#  {'user': '1280', 'time': 'A', 'pattern': (8, 7)},
#  {'user': '1280', 'time': 'A', 'pattern': (12, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (7, 5)},
#  {'user': '1280', 'time': 'A', 'pattern': (8, 18)},
#  {'user': '1280', 'time': 'A', 'pattern': (50, 10)},
#  {'user': '1280', 'time': 'A', 'pattern': (9, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (23, 5)},
#  {'user': '1280', 'time': 'A', 'pattern': (6, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (26, 10)},
#  {'user': '1280', 'time': 'A', 'pattern': (7, 7)},
#  {'user': '1280', 'time': 'A', 'pattern': (15, 33)},
#  {'user': '1280', 'time': 'A', 'pattern': (5, 4)},
#  {'user': '1280', 'time': 'A', 'pattern': (2, 22)},
#  {'user': '1280', 'time': 'A', 'pattern': (6, 10)},
#  {'user': '1280', 'time': 'A', 'pattern': (6, 8)},
#  {'user': '1280', 'time': 'A', 'pattern': (14, 9)},
#  {'user': '1280', 'time': 'A', 'pattern': (26, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (8, 7)},
#  {'user': '1280', 'time': 'A', 'pattern': (6, 6)},
#  {'user': '1280', 'time': 'A', 'pattern': (19, 3)},
#  {'user': '1280', 'time': 'A', 'pattern': (7, 8)},
#  {'user': '1280', 'time': 'A', 'pattern': (26, 8)},
#  {'user': '1280', 'time': 'A', 'pattern': (43, 13)},
#  {'user': '1280', 'time': 'A', 'pattern': (10, 14)},
#  {'user': '1280', 'time': 'A', 'pattern': (12, 15)},
#  {'user': '1280', 'time': 'A', 'pattern': (13, 13)},
#  {'user': '1280', 'time': 'A', 'pattern': (4, 7)},
#  {'user': '1280', 'time': 'A', 'pattern': (46, 12)},
#  {'user': '1280', 'time': 'A', 'pattern': (8, 2)},
#  {'user': '1280', 'time': 'A', 'pattern': (0, 34)},
#  {'user': '1280', 'time': 'A', 'pattern': (15, 15)},
#  {'user': '1280', 'time': 'A', 'pattern': (39, 2)},
#  {'user': '1280', 'time': 'E', 'pattern': (22, 3)},
#  {'user': '1280', 'time': 'E', 'pattern': (18, 1)},
#  {'user': '1280', 'time': 'E', 'pattern': (6, 10)},
#  {'user': '1280', 'time': 'E', 'pattern': (6, 6)},
#  {'user': '1280', 'time': 'E', 'pattern': (5, 7)},
#  {'user': '1280', 'time': 'E', 'pattern': (11, 4)},
#  {'user': '1280', 'time': 'E', 'pattern': (14, 0)},
#  {'user': '1280', 'time': 'E', 'pattern': (10, 0)},
#  {'user': '1280', 'time': 'E', 'pattern': (8, 7)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 15)},
#  {'user': '198', 'time': 'M', 'pattern': (8, 25)},
#  {'user': '198', 'time': 'M', 'pattern': (14, 14)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (19, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 18)},
#  {'user': '198', 'time': 'M', 'pattern': (11, 17)},
#  {'user': '198', 'time': 'M', 'pattern': (11, 19)},
#  {'user': '198', 'time': 'M', 'pattern': (16, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (3, 37)},
#  {'user': '198', 'time': 'M', 'pattern': (22, 30)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (25, 3)},
#  {'user': '198', 'time': 'M', 'pattern': (17, 31)},
#  {'user': '198', 'time': 'M', 'pattern': (23, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (19, 17)},
#  {'user': '198', 'time': 'M', 'pattern': (24, 26)},
#  {'user': '198', 'time': 'M', 'pattern': (16, 15)},
#  {'user': '198', 'time': 'M', 'pattern': (23, 11)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 14)},
#  {'user': '198', 'time': 'M', 'pattern': (18, 6)},
#  {'user': '198', 'time': 'M', 'pattern': (16, 16)},
#  {'user': '198', 'time': 'M', 'pattern': (13, 20)},
#  {'user': '198', 'time': 'M', 'pattern': (15, 26)},
#  {'user': '198', 'time': 'M', 'pattern': (12, 7)},
#  {'user': '198', 'time': 'M', 'pattern': (25, 9)},
#  {'user': '198', 'time': 'A', 'pattern': (13, 16)},
#  {'user': '198', 'time': 'A', 'pattern': (3, 22)},
#  {'user': '198', 'time': 'A', 'pattern': (14, 18)},
#  {'user': '198', 'time': 'A', 'pattern': (21, 10)},
#  {'user': '198', 'time': 'A', 'pattern': (15, 4)},
#  {'user': '198', 'time': 'A', 'pattern': (14, 7)},
#  {'user': '198', 'time': 'A', 'pattern': (14, 10)},
#  {'user': '198', 'time': 'A', 'pattern': (10, 39)},
#  {'user': '198', 'time': 'A', 'pattern': (12, 18)},
#  {'user': '198', 'time': 'A', 'pattern': (26, 29)},
#  {'user': '198', 'time': 'A', 'pattern': (16, 15)},
#  {'user': '198', 'time': 'A', 'pattern': (18, 14)},
#  {'user': '198', 'time': 'A', 'pattern': (12, 23)},
#  {'user': '198', 'time': 'E', 'pattern': (44, 4)},
#  {'user': '198', 'time': 'E', 'pattern': (14, 7)},
#  {'user': '198', 'time': 'E', 'pattern': (32, 4)},
#  {'user': '198', 'time': 'E', 'pattern': (2, 4)},
#  {'user': '198', 'time': 'E', 'pattern': (14, 16)},
#  {'user': '198', 'time': 'E', 'pattern': (26, 18)},
#  {'user': '2447', 'time': 'M', 'pattern': (32, 14)},
#  {'user': '2447', 'time': 'M', 'pattern': (30, 7)},
#  {'user': '2447', 'time': 'M', 'pattern': (23, 8)},
#  {'user': '2447', 'time': 'M', 'pattern': (28, 4)},
#  {'user': '2447', 'time': 'M', 'pattern': (27, 5)},
#  {'user': '2447', 'time': 'M', 'pattern': (27, 4)},
#  {'user': '2447', 'time': 'M', 'pattern': (30, 5)},
#  {'user': '2447', 'time': 'M', 'pattern': (32, 9)},
#  {'user': '2447', 'time': 'M', 'pattern': (32, 12)},
#  {'user': '2447', 'time': 'M', 'pattern': (29, 4)},
#  {'user': '2447', 'time': 'M', 'pattern': (25, 6)},
#  {'user': '2447', 'time': 'M', 'pattern': (59, 18)},
#  {'user': '2447', 'time': 'M', 'pattern': (25, 3)},
#  {'user': '2447', 'time': 'M', 'pattern': (19, 24)},
#  {'user': '2447', 'time': 'M', 'pattern': (3, 55)},
#  {'user': '2447', 'time': 'M', 'pattern': (22, 7)},
#  {'user': '2447', 'time': 'M', 'pattern': (27, 3)},
#  {'user': '2447', 'time': 'M', 'pattern': (23, 5)},
#  {'user': '2447', 'time': 'A', 'pattern': (46, 10)},
#  {'user': '2447', 'time': 'A', 'pattern': (50, 12)},
#  {'user': '2447', 'time': 'A', 'pattern': (21, 3)},
#  {'user': '2447', 'time': 'E', 'pattern': (28, 5)},
#  {'user': '2447', 'time': 'E', 'pattern': (1, 1)},
#  {'user': '2447', 'time': 'E', 'pattern': (29, 5)},
#  {'user': '2447', 'time': 'E', 'pattern': (28, 13)},
#  {'user': '2447', 'time': 'E', 'pattern': (43, 10)},
#  {'user': '2447', 'time': 'E', 'pattern': (28, 8)},
#  {'user': '2447', 'time': 'E', 'pattern': (26, 5)},
#  {'user': '2447', 'time': 'E', 'pattern': (27, 6)},
#  {'user': '2447', 'time': 'E', 'pattern': (28, 5)},
#  {'user': '2447', 'time': 'E', 'pattern': (15, 26)},
#  {'user': '2447', 'time': 'E', 'pattern': (27, 15)},
#  {'user': '2447', 'time': 'E', 'pattern': (8, 39)},
#  {'user': '2447', 'time': 'E', 'pattern': (36, 16)},
#  {'user': '2447', 'time': 'E', 'pattern': (21, 13)},
#  {'user': '2447', 'time': 'E', 'pattern': (28, 7)},
#  {'user': '2447', 'time': 'E', 'pattern': (26, 3)},
#  {'user': '2447', 'time': 'E', 'pattern': (24, 17)},
#  {'user': '2447', 'time': 'E', 'pattern': (28, 6)},
#  {'user': '2447', 'time': 'E', 'pattern': (36, 10)},
#  {'user': '2447', 'time': 'E', 'pattern': (27, 9)},
#  {'user': '2447', 'time': 'E', 'pattern': (32, 18)},
#  {'user': '1838', 'time': 'M', 'pattern': (27, 17)},
#  {'user': '1838', 'time': 'M', 'pattern': (45, 11)},
#  {'user': '1838', 'time': 'M', 'pattern': (43, 9)},
#  {'user': '1838', 'time': 'M', 'pattern': (36, 51)},
#  {'user': '1838', 'time': 'M', 'pattern': (31, 19)},
#  {'user': '1838', 'time': 'M', 'pattern': (32, 17)},
#  {'user': '1838', 'time': 'M', 'pattern': (56, 24)},
#  {'user': '1838', 'time': 'M', 'pattern': (30, 17)},
#  {'user': '1838', 'time': 'M', 'pattern': (33, 26)},
#  {'user': '1838', 'time': 'M', 'pattern': (32, 19)},
#  {'user': '1838', 'time': 'M', 'pattern': (33, 17)},
#  {'user': '1838', 'time': 'M', 'pattern': (29, 20)},
#  {'user': '1838', 'time': 'M', 'pattern': (26, 24)},
#  {'user': '1838', 'time': 'M', 'pattern': (23, 18)},
#  {'user': '1838', 'time': 'M', 'pattern': (25, 27)},
#  {'user': '1838', 'time': 'M', 'pattern': (28, 21)},
#  {'user': '1838', 'time': 'M', 'pattern': (28, 21)},
#  {'user': '1838', 'time': 'M', 'pattern': (28, 18)},
#  {'user': '1838', 'time': 'M', 'pattern': (30, 21)},
#  {'user': '1838', 'time': 'M', 'pattern': (40, 20)},
#  {'user': '1838', 'time': 'M', 'pattern': (36, 7)},
#  {'user': '1838', 'time': 'M', 'pattern': (27, 21)},
#  {'user': '1838', 'time': 'M', 'pattern': (11, 36)},
#  {'user': '1838', 'time': 'M', 'pattern': (38, 20)},
#  {'user': '1838', 'time': 'A', 'pattern': (25, 24)},
#  {'user': '1838', 'time': 'A', 'pattern': (37, 30)},
#  {'user': '1838', 'time': 'A', 'pattern': (26, 54)},
#  {'user': '1838', 'time': 'A', 'pattern': (11, 27)},
#  {'user': '1838', 'time': 'A', 'pattern': (30, 11)},
#  {'user': '1838', 'time': 'A', 'pattern': (39, 27)},
#  {'user': '1838', 'time': 'E', 'pattern': (38, 37)},
#  {'user': '1838', 'time': 'E', 'pattern': (32, 16)},
#  {'user': '1838', 'time': 'E', 'pattern': (37, 18)},
#  {'user': '1838', 'time': 'E', 'pattern': (30, 31)},
#  {'user': '1838', 'time': 'E', 'pattern': (29, 16)},
#  {'user': '1838', 'time': 'E', 'pattern': (27, 19)},
#  {'user': '1838', 'time': 'E', 'pattern': (29, 25)},
#  {'user': '1838', 'time': 'E', 'pattern': (12, 46)},
#  {'user': '1838', 'time': 'E', 'pattern': (30, 21)},
#  {'user': '1838', 'time': 'E', 'pattern': (25, 16)},
#  {'user': '1838', 'time': 'E', 'pattern': (28, 22)},
#  {'user': '1838', 'time': 'E', 'pattern': (27, 3)},
#  {'user': '1838', 'time': 'E', 'pattern': (37, 27)},
#  {'user': '1838', 'time': 'E', 'pattern': (30, 21)},
#  {'user': '1838', 'time': 'E', 'pattern': (33, 20)},
#  {'user': '1838', 'time': 'E', 'pattern': (28, 21)},
#  {'user': '3105', 'time': 'M', 'pattern': (4, 53)},
#  {'user': '3105', 'time': 'M', 'pattern': (2, 52)},
#  {'user': '3105', 'time': 'M', 'pattern': (19, 65)},
#  {'user': '3105', 'time': 'M', 'pattern': (18, 63)},
#  {'user': '3105', 'time': 'M', 'pattern': (17, 66)},
#  {'user': '3105', 'time': 'M', 'pattern': (12, 66)},
#  {'user': '3105', 'time': 'M', 'pattern': (24, 65)},
#  {'user': '3105', 'time': 'M', 'pattern': (10, 54)},
#  {'user': '3105', 'time': 'M', 'pattern': (25, 52)},
#  {'user': '3105', 'time': 'M', 'pattern': (1, 58)},
#  {'user': '3105', 'time': 'M', 'pattern': (37, 35)},
#  {'user': '3105', 'time': 'M', 'pattern': (18, 35)},
#  {'user': '3105', 'time': 'M', 'pattern': (18, 50)},
#  {'user': '3105', 'time': 'M', 'pattern': (15, 63)},
#  {'user': '3105', 'time': 'M', 'pattern': (16, 65)},
#  {'user': '3105', 'time': 'M', 'pattern': (19, 66)},
#  {'user': '3105', 'time': 'M', 'pattern': (17, 65)},
#  {'user': '3105', 'time': 'M', 'pattern': (16, 59)},
#  {'user': '3105', 'time': 'M', 'pattern': (6, 51)},
#  {'user': '3105', 'time': 'M', 'pattern': (19, 63)},
#  {'user': '3105', 'time': 'M', 'pattern': (16, 42)},
#  {'user': '3105', 'time': 'M', 'pattern': (21, 46)},
#  {'user': '3105', 'time': 'M', 'pattern': (18, 64)},
#  {'user': '3105', 'time': 'M', 'pattern': (16, 63)},
#  {'user': '3105', 'time': 'M', 'pattern': (18, 37)},
#  {'user': '3105', 'time': 'M', 'pattern': (26, 41)},
#  {'user': '3105', 'time': 'M', 'pattern': (17, 50)},
#  {'user': '3105', 'time': 'M', 'pattern': (33, 34)},
#  {'user': '3105', 'time': 'M', 'pattern': (21, 63)},
#  {'user': '3105', 'time': 'M', 'pattern': (18, 47)},
#  {'user': '3105', 'time': 'M', 'pattern': (2, 53)},
#  {'user': '3105', 'time': 'M', 'pattern': (30, 48)},
#  {'user': '3105', 'time': 'M', 'pattern': (17, 59)},
#  {'user': '3105', 'time': 'M', 'pattern': (20, 64)},
#  {'user': '3105', 'time': 'M', 'pattern': (20, 60)},
#  {'user': '3105', 'time': 'M', 'pattern': (20, 51)},
#  {'user': '3105', 'time': 'M', 'pattern': (13, 63)},
#  {'user': '3105', 'time': 'M', 'pattern': (19, 34)},
#  {'user': '3105', 'time': 'M', 'pattern': (20, 65)},
#  {'user': '3105', 'time': 'M', 'pattern': (17, 61)},
#  {'user': '3105', 'time': 'M', 'pattern': (30, 31)},
#  {'user': '3105', 'time': 'M', 'pattern': (20, 61)},
#  {'user': '3105', 'time': 'M', 'pattern': (20, 65)},
#  {'user': '3105', 'time': 'M', 'pattern': (41, 45)},
#  {'user': '3105', 'time': 'A', 'pattern': (21, 61)},
#  {'user': '3105', 'time': 'A', 'pattern': (38, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (9, 60)},
#  {'user': '3105', 'time': 'A', 'pattern': (19, 59)},
#  {'user': '3105', 'time': 'A', 'pattern': (2, 38)},
#  {'user': '3105', 'time': 'A', 'pattern': (12, 50)},
#  {'user': '3105', 'time': 'A', 'pattern': (21, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (19, 65)},
#  {'user': '3105', 'time': 'A', 'pattern': (16, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (16, 18)},
#  {'user': '3105', 'time': 'A', 'pattern': (3, 24)},
#  {'user': '3105', 'time': 'A', 'pattern': (17, 63)},
#  {'user': '3105', 'time': 'A', 'pattern': (18, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (14, 34)},
#  {'user': '3105', 'time': 'A', 'pattern': (17, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (19, 65)},
#  {'user': '3105', 'time': 'A', 'pattern': (24, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (18, 57)},
#  {'user': '3105', 'time': 'A', 'pattern': (30, 37)},
#  {'user': '3105', 'time': 'A', 'pattern': (15, 66)},
#  {'user': '3105', 'time': 'A', 'pattern': (19, 63)},
#  {'user': '3105', 'time': 'A', 'pattern': (20, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (19, 63)},
#  {'user': '3105', 'time': 'A', 'pattern': (55, 32)},
#  {'user': '3105', 'time': 'A', 'pattern': (16, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (20, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (28, 57)},
#  {'user': '3105', 'time': 'A', 'pattern': (12, 62)},
#  {'user': '3105', 'time': 'A', 'pattern': (21, 42)},
#  {'user': '3105', 'time': 'A', 'pattern': (23, 65)},
#  {'user': '3105', 'time': 'A', 'pattern': (15, 64)},
#  {'user': '3105', 'time': 'A', 'pattern': (20, 51)},
#  {'user': '3105', 'time': 'A', 'pattern': (18, 12)},
#  {'user': '3105', 'time': 'E', 'pattern': (2, 48)},
#  {'user': '3105', 'time': 'E', 'pattern': (5, 51)},
#  {'user': '3105', 'time': 'E', 'pattern': (19, 64)},
#  {'user': '3910', 'time': 'M', 'pattern': (29, 20)},
#  {'user': '3910', 'time': 'M', 'pattern': (12, 15)},
#  {'user': '3910', 'time': 'M', 'pattern': (13, 25)},
#  {'user': '3910', 'time': 'M', 'pattern': (7, 14)},
#  {'user': '3910', 'time': 'M', 'pattern': (34, 25)},
#  {'user': '3910', 'time': 'M', 'pattern': (2, 13)},
#  {'user': '3910', 'time': 'M', 'pattern': (10, 18)},
#  {'user': '3910', 'time': 'M', 'pattern': (5, 13)},
#  {'user': '3910', 'time': 'M', 'pattern': (10, 10)},
#  {'user': '3910', 'time': 'M', 'pattern': (5, 13)},
#  {'user': '3910', 'time': 'M', 'pattern': (27, 43)},
#  {'user': '3910', 'time': 'M', 'pattern': (25, 29)},
#  {'user': '3910', 'time': 'M', 'pattern': (8, 17)},
#  {'user': '3910', 'time': 'M', 'pattern': (10, 29)},
#  {'user': '3910', 'time': 'M', 'pattern': (6, 14)},
#  {'user': '3910', 'time': 'M', 'pattern': (6, 13)},
#  {'user': '3910', 'time': 'M', 'pattern': (9, 21)},
#  {'user': '3910', 'time': 'M', 'pattern': (5, 11)},
#  {'user': '3910', 'time': 'M', 'pattern': (7, 13)},
#  {'user': '3910', 'time': 'A', 'pattern': (24, 23)},
#  {'user': '3910', 'time': 'A', 'pattern': (11, 21)},
#  {'user': '3910', 'time': 'A', 'pattern': (6, 15)},
#  {'user': '3910', 'time': 'A', 'pattern': (6, 10)},
#  {'user': '3910', 'time': 'A', 'pattern': (3, 21)},
#  {'user': '3910', 'time': 'A', 'pattern': (5, 15)},
#  {'user': '3910', 'time': 'A', 'pattern': (6, 14)},
#  {'user': '3910', 'time': 'A', 'pattern': (16, 1)},
#  {'user': '3910', 'time': 'A', 'pattern': (6, 14)},
#  {'user': '3910', 'time': 'A', 'pattern': (9, 12)},
#  {'user': '3910', 'time': 'A', 'pattern': (13, 15)},
#  {'user': '3910', 'time': 'A', 'pattern': (10, 15)},
#  {'user': '3910', 'time': 'A', 'pattern': (35, 5)},
#  {'user': '1680', 'time': 'M', 'pattern': (52, 2)},
#  {'user': '1680', 'time': 'M', 'pattern': (57, 0)},
#  {'user': '1680', 'time': 'M', 'pattern': (51, 3)},
#  {'user': '1680', 'time': 'M', 'pattern': (52, 1)},
#  {'user': '1680', 'time': 'M', 'pattern': (52, 3)},
#  {'user': '1680', 'time': 'M', 'pattern': (62, 3)},
#  {'user': '1680', 'time': 'M', 'pattern': (62, 16)},
#  {'user': '1680', 'time': 'M', 'pattern': (49, 13)},
#  {'user': '1680', 'time': 'M', 'pattern': (50, 2)},
#  {'user': '1680', 'time': 'M', 'pattern': (54, 4)},
#  {'user': '1680', 'time': 'M', 'pattern': (56, 2)},
#  {'user': '1680', 'time': 'M', 'pattern': (3, 11)},
#  {'user': '1680', 'time': 'M', 'pattern': (54, 1)},
#  {'user': '1680', 'time': 'M', 'pattern': (50, 3)},
#  {'user': '1680', 'time': 'M', 'pattern': (8, 5)},
#  {'user': '1680', 'time': 'M', 'pattern': (52, 6)},
#  {'user': '1680', 'time': 'M', 'pattern': (52, 6)},
#  {'user': '1680', 'time': 'M', 'pattern': (48, 4)},
#  {'user': '1680', 'time': 'M', 'pattern': (51, 5)},
#  {'user': '1680', 'time': 'M', 'pattern': (33, 22)},
#  {'user': '1680', 'time': 'M', 'pattern': (57, 13)},
#  {'user': '1680', 'time': 'M', 'pattern': (47, 0)},
#  {'user': '1680', 'time': 'M', 'pattern': (53, 10)},
#  {'user': '1680', 'time': 'M', 'pattern': (43, 30)},
#  {'user': '1680', 'time': 'M', 'pattern': (47, 5)},
#  {'user': '1680', 'time': 'M', 'pattern': (47, 40)},
#  {'user': '1680', 'time': 'M', 'pattern': (51, 3)},
#  {'user': '1680', 'time': 'M', 'pattern': (48, 5)},
#  {'user': '1680', 'time': 'M', 'pattern': (59, 13)},
#  {'user': '1680', 'time': 'M', 'pattern': (55, 10)},
#  {'user': '1680', 'time': 'M', 'pattern': (63, 9)},
#  {'user': '1680', 'time': 'M', 'pattern': (43, 9)},
#  {'user': '1680', 'time': 'M', 'pattern': (55, 0)},
#  {'user': '1680', 'time': 'M', 'pattern': (52, 0)},
#  {'user': '1680', 'time': 'M', 'pattern': (21, 8)},
#  {'user': '1680', 'time': 'M', 'pattern': (34, 1)},
#  {'user': '1680', 'time': 'M', 'pattern': (47, 1)},
#  {'user': '1680', 'time': 'M', 'pattern': (49, 2)},
#  {'user': '1680', 'time': 'M', 'pattern': (46, 15)},
#  ...]

# %%
with open("dict13.csv", 'w') as file:
    header = ['user', 'time', 'pattern']
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
            
    for element in wjlist:
        writer.writerow(element)
